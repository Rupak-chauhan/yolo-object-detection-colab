# %%
from ultralytics import YOLO

# Train 

# model = YOLO('yolov8n.pt')
# model.train(data="data.yaml", epochs=200, imgsz=608, batch=8, save=True, save_crop=True)
# print("Executed");
# return {"response": "Trained model successfully."}

# Validation

# model = YOLO('best.pt")
# # Customize validation settings
# metrics = model.val(data="data.yaml", epochs=200, imgsz=608, batch=8, conf=0.25, save=True)
# print("MAPS ==>", metrics.box.maps)
# return {"Hello": "Validate model successsfully."}

# Testing
# model = YOLO("best.pt")

# # Customize validation settings
# results = model.predict("test_images", epochs=200, save=True, show= True, imgsz=608, batch=8, conf=0.25)
# for r in results:
#     print("Box ==> ", r.boxes)
#     # model.predict("bus.jpg", save=True, imgsz=320, conf=0.5)
# return {"Hello": "Predicted model successfully."}

# %%
# Augmentation Pipeline
# !pip install -U albumentations

import albumentations as A
import os
import cv2
import numpy as np

img_path = "./datasets/train/images"
labels_path = "./datasets/train/labels"

# Get the list of all files in images directories
dir_list = os.listdir(img_path)
print("All Images Files :", dir_list)

# Converting back to yolo format and same in labels file from the response of generate augmented boxes
def convert_to_yolo_format(data, name):
    print("convert_to_yolo_format :");
    mapping_classes = ['Person', '2-wheeler', '4-wheeler']
    # Define the file path where you want to save the data
    file_path = labels_path + "/" + namecal
    
    # Open the file in write mode ('w')
    with open(file_path, 'w') as file:
        for tuple_data in data:
            # Get the last element (class type)
            class_name = tuple_data[-1]
            # Find its index in the mapping array
            mapped_index = mapping_classes.index(class_name)
            # Convert the tuple to a list to modify it
            modified_list = list(tuple_data)
            # Insert the mapped index at the beginning of the list
            modified_list.insert(0, mapped_index)
            modified_list.pop()
            # Convert each element of the modified list to a string
            # Join them with a space and create a single string to write to the file
            line = ' '.join(map(str, modified_list))
            # Write the line to the file
            file.write(line + '\n')
    
    print(f'label Data saved to {file_path}')
    

# construct the actual format with mapping classes
def construct_mapping(data):
    print("---------Inside construct_mapping-------------")
    mapping_classes = ['Person', '2-wheeler', '4-wheeler']
    # Convert the data to a list of lists of floats and move the 0th index element to the end
    mapped_data = []
    for sublist in data:
        split_items = sublist[0].split()
        if len(split_items):
            first_element = mapping_classes[int(split_items[0])]
            remaining_elements = [float(item) for item in split_items[1:]]
            remaining_elements.append(first_element)
            mapped_data.append(remaining_elements)
        
    return mapped_data
    
# method to choose label for corresponding image and converting it for  albumentations format
def get_formatted_label(fl_name):
    print("---------Inside get_formatted_label -------------")
    fl_label_path = labels_path + "/" + os.path.splitext(fl_name)[0] + ".txt"
    fs = open(fl_label_path);
    fs_content = fs.read().split("\n");
    temp_lst = []
    for each_label in fs_content:
        temp_lst.append([each_label])
    # print("fs_content :" + fl_label_path, temp_lst)
    mapped_data = construct_mapping(temp_lst)
    # print("mapped_data :", mapped_data);
    return mapped_data
    
# Read the each file one by one and format labels & pass through augmentation pipeline

def augmentation_pipeline(img, box_labels, fl_name):
    print("---------Inside Augmentation Pipeline-------------")
    
    for val in ["aug_flip_", "aug_rotate_", "aug_scale_"]:
        if val == "aug_flip_":
             transform = A.Compose([
                A.Flip(p=0.8)
             ], bbox_params=A.BboxParams(format='yolo'))
        
             transformed = transform(image=img, bboxes=box_labels)
             transformed_image = transformed['image']
             transformed_bboxes = transformed['bboxes']
             print("transformed_image :", len(transformed_image), "transformed_bboxes :", transformed_bboxes);
           
             cv2.imwrite(img_path + "/" + val + fl_name, transformed_image)
             convert_to_yolo_format(transformed_bboxes, val + os.path.splitext(fl_name)[0] + ".txt")
        
        elif val == "aug_rotate_":
               transform = A.Compose([
                A.Rotate(limit=180, p=0.8)
               ], bbox_params=A.BboxParams(format='yolo'))
        
               transformed = transform(image=img, bboxes=box_labels)
               transformed_image = transformed['image']
               transformed_bboxes = transformed['bboxes']
               print("transformed_image :", len(transformed_image), "transformed_bboxes :", transformed_bboxes);
               
               cv2.imwrite(img_path + "/" + val + fl_name, transformed_image)
               convert_to_yolo_format(transformed_bboxes, val + os.path.splitext(fl_name)[0] + ".txt")
        
        elif val == "aug_scale_":
               transform = A.Compose([
                A.RandomScale(scale_limit=(0.5, 2.0), p=0.5)
               ], bbox_params=A.BboxParams(format='yolo'))
        
               transformed = transform(image=img, bboxes=box_labels)
               transformed_image = transformed['image']
               transformed_bboxes = transformed['bboxes']
               print("transformed_image :", len(transformed_image), "transformed_bboxes :", transformed_bboxes);
               
               cv2.imwrite(img_path + "/" + val + fl_name, transformed_image)
               convert_to_yolo_format(transformed_bboxes, val + os.path.splitext(fl_name)[0] + ".txt")
    
    
for fl_name in dir_list:
    img = cv2.imread(img_path + "/" + fl_name)
    # print("img :", img, np.array(img))
    box_labels = get_formatted_label(fl_name)
    augmentation_pipeline(img, box_labels, fl_name)
    # print(" File Name :", fl_name, "-- Box Label -- :", box_labels)
    # break;
# Out:
# All Images Files : ['2-wheelers-2.jpg', '2-wheelers_1.jpg', '4-wheelers-1.jpg', '4-wheelers_2.jpg', 'combined-1.jpg', 'combined-3.jpg', 'person_1.jpg', 'person_2.jpg']
# ---------Inside get_formatted_label -------------
# ---------Inside construct_mapping-------------
# ---------Inside Augmentation Pipeline-------------
# transformed_image : 3543 transformed_bboxes : [(0.526491, 0.22805499999999995, 0.7092199999999999, 0.303697, '2-wheeler')]
# convert_to_yolo_format :
# label Data saved to ./datasets/train/labels/aug_flip_2-wheelers-2.txt
# transformed_image : 3543 transformed_bboxes : [(0.25753360954149895, 0.6395505526948165, 0.5150672190829979, 0.5654250496923403, '2-wheeler')]
# convert_to_yolo_format :
# label Data saved to ./datasets/train/labels/aug_rotate_2-wheelers-2.txt
# transformed_image : 3543 transformed_bboxes : [(0.526491, 0.7719450000000001, 0.7092199999999999, 0.3036970000000001, '2-wheeler')]
# convert_to_yolo_format :
# label Data saved to ./datasets/train/labels/aug_scale_2-wheelers-2.txt
# ---------Inside get_formatted_label -------------
# ---------Inside construct_mapping-------------
# ---------Inside Augmentation Pipeline-------------
# transformed_image : 2137 transformed_bboxes : [(0.673791, 0.306504, 0.4926680000000001, 0.5605990000000001, '2-wheeler')]
# convert_to_yolo_format :
# label Data saved to ./datasets/train/labels/aug_flip_2-wheelers_1.txt
# transformed_image : 2137 transformed_bboxes : [(0.3289339673088446, 0.30111706515312553, 0.5003466974511139, 0.5758674277355651, '2-wheeler')]
# convert_to_yolo_format :
# label Data saved to ./datasets/train/labels/aug_rotate_2-wheelers_1.txt
# transformed_image : 2137 transformed_bboxes : [(0.673791, 0.693496, 0.4926680000000001, 0.5605990000000001, '2-wheeler')]
# convert_to_yolo_format :
# label Data saved to ./datasets/train/labels/aug_scale_2-wheelers_1.txt
# ---------Inside get_formatted_label -------------
# ---------Inside construct_mapping-------------
# ---------Inside Augmentation Pipeline-------------
# transformed_image : 3648 transformed_bboxes : [(0.691886, 0.646793, 0.42470799999999986, 0.228344, '4-wheeler'), (0.1094659999999999, 0.7261509999999999, 0.216009, 0.0833330000000001, '4-wheeler')]
# convert_to_yolo_format :
# label Data saved to ./datasets/train/labels/aug_flip_4-wheelers-1.txt
# transformed_image : 3648 transformed_bboxes : [(0.3834793006176537, 0.6860711272079577, 0.501403698921449, 0.32069222961057675, '4-wheeler'), (0.9239454108741062, 0.6167867030121732, 0.1521091782517876, 0.13214069414590657, '4-wheeler')]
# convert_to_yolo_format :
# label Data saved to ./datasets/train/labels/aug